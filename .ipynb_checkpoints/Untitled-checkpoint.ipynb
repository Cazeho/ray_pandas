# %% [markdown]
# # 1. Initialization

# %%
import ray
import pandas as pd
import time 
import numpy as np
import binascii
import redis
import pprint
import json
pp = pprint.PrettyPrinter() # for printing dicts and lists in a manner easy for the eyes
from misc import *

# %%
ray.init(num_cpus=3)
# Out:
# Waiting for redis server at 127.0.0.1:29293 to respond...
# Waiting for redis server at 127.0.0.1:60831 to respond...
# Starting local scheduler with 3 CPUs and 0 GPUs.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-22-7a0ab5952465> in <module>()
# ----> 1 ray.init(num_cpus=3)
#
# /Users/michellemarzoev/.local/lib/python3.6/site-packages/ray-0.1.1-py3.6-macosx-10.7-x86_64.egg/ray/worker.py in init(redis_address, node_ip_address, object_id_seed, num_workers, driver_mode, redirect_output, num_cpus, num_gpus, num_redis_shards)
#     954                num_workers=num_workers, driver_mode=driver_mode,
#     955                redirect_output=redirect_output, num_cpus=num_cpus,
# --> 956                num_gpus=num_gpus, num_redis_shards=num_redis_shards)
#     957
#     958
#
# /Users/michellemarzoev/.local/lib/python3.6/site-packages/ray-0.1.1-py3.6-macosx-10.7-x86_64.egg/ray/worker.py in _init(address_info, start_ray_local, object_id_seed, num_workers, num_local_schedulers, driver_mode, redirect_output, start_workers_from_local_scheduler, num_cpus, num_gpus, num_redis_shards)
#     906                                         ["local_scheduler_socket_names"][0])}
#     907   connect(driver_address_info, object_id_seed=object_id_seed, mode=driver_mode,
# --> 908           worker=global_worker, actor_id=NIL_ACTOR_ID)
#     909   return address_info
#     910
#
# /Users/michellemarzoev/.local/lib/python3.6/site-packages/ray-0.1.1-py3.6-macosx-10.7-x86_64.egg/ray/worker.py in connect(info, object_id_seed, mode, worker, actor_id)
#    1236   # Do some basic checking to make sure we didn't call ray.init twice.
#    1237   error_message = "Perhaps you called ray.init twice by accident?"
# -> 1238   assert not worker.connected, error_message
#    1239   assert worker.cached_functions_to_run is not None, error_message
#    1240   assert worker.cached_remote_functions is not None, error_message
#
# AssertionError: Perhaps you called ray.init twice by accident?

# %% [markdown]
# ### Function definitions

# %%
@ray.remote
def example(x):
    time.sleep(np.random.random())
    return np.random.randn()

@ray.remote
def example2(x): 
    return "hi"

@ray.remote
class TestCls():
    def __init__(self):
        self.g = 1
        
    def to_go(self, x):
        return x

    
@ray.remote
class Outer():
    def __init__(self):
        self.f = 1
        self.test = TestCls.remote()
    
    def to_go2(self, x):
        return x * 2
    
    def error(self):
        return 1/0

# %% [markdown]
# ### Generate data in Redis

# %%
# Here, we generate data in redis for remote tasks
results = ray.get([example.remote(x) for x in range(4)])

results2 = ray.get([example2.remote(x) for x in range(20)])

# Generating data for Actor tasks
actor = TestCls.remote()
actor_results = ray.get([actor.to_go.remote(1)])

err_actor = Outer.remote()
err_actor.error.remote()
# Out:
# ObjectID(bd4f813beacefcd6c2a4136f5acaed4b7be402dc)

# %% [markdown]
# ### Connect to Redis

# %%
addr, port = ray.worker.global_worker.redis_address.split(":")
rc = redis.StrictRedis(host=addr, port=port, decode_responses=False)
# Out:
# Remote function error failed with:
#
# Traceback (most recent call last):
#   File "/Users/michellemarzoev/.local/lib/python3.6/site-packages/ray-0.1.1-py3.6-macosx-10.7-x86_64.egg/ray/worker.py", line 1754, in process_task
#     worker.actors[task.actor_id().id()], *arguments)
#   File "<ipython-input-4-c197885e48f2>", line 29, in error
# ZeroDivisionError: division by zero
#
#
# You can inspect errors by running
#
#     ray.error_info()
#
# If this driver is hanging, start a new one with
#
#     ray.init(redis_address="127.0.0.1:16122")

# %% [markdown]
# # 2. Jobs Data

# %% [markdown]
# ### Remote Functions Information

# %%
fn_table = ray.global_state.function_table()
fn_list = []
for fn_id in fn_table:
    val = fn_table[fn_id]
    val["function_id"] = fn_id
    fn_list.append(val)
pd.DataFrame(fn_list)
# Out:
#                                    DriverID    Module               Name  \
# 0  54229a6451eb838faae8e8df707cabddc19c7244  __main__   __main__.example
# 1  54229a6451eb838faae8e8df707cabddc19c7244  __main__  __main__.example2
#
#                                 function_id
# 0  cf1fc498b8a2b4cb79bc2ed5abf074ba96ae69a1
# 1  2eba3bed62c6ec0773f74488ccde2404b45f5a0a

# %% [markdown]
# ### Task - Worker Placement Information

# %%
event_names = rc.keys("event_log*")
results = dict()
for i in range(len(event_names)):
  event_list = rc.lrange(event_names[i], 0, -1)
  for event in event_list:
    event_dict = json.loads(event.decode("ascii"))
    task_id = ""
    worker_id = ""
    function_name = ""
    for element in event_dict:
      if "task_id" in element[3] and "worker_id" in element[3]:
        task_id = element[3]["task_id"]
        worker_id = element[3]["worker_id"]
        function_name = element[3]["function_name"]
    if task_id != "" and worker_id != "" and function_name != "":
      if worker_id not in results:
        results[worker_id] = []
      inner_dict = dict()
      inner_dict["task_id"] = task_id
      inner_dict["function_name"] = function_name
      results[worker_id].append(inner_dict)
results_table = pd.DataFrame(results)
results_table
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-1347b83882c4> in <module>()
#      20       inner_dict["function_name"] = function_name
#      21       results[worker_id].append(inner_dict)
# ---> 22 results_table = pd.DataFrame(results)
#      23 results_table
#
# /Users/michellemarzoev/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
# --> 275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     276         elif isinstance(data, ma.MaskedArray):
#     277             import numpy.ma.mrecords as mrecords
#
# /Users/michellemarzoev/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     409             arrays = [data[k] for k in keys]
#     410
# --> 411         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     412
#     413     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /Users/michellemarzoev/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5592     # figure out the index, if necessary
#    5593     if index is None:
# -> 5594         index = extract_index(arrays)
#    5595     else:
#    5596         index = _ensure_index(index)
#
# /Users/michellemarzoev/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    5640             lengths = list(set(raw_lengths))
#    5641             if len(lengths) > 1:
# -> 5642                 raise ValueError('arrays must all be same length')
#    5643
#    5644             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# # 3. System State

# %% [markdown]
# ### Node Information

# %%
# Using the global state API, we can populate a DataFrame with a list of Redis Clients currently connected
ctable = ray.global_state.client_table()

client_list = []
for node_ip in ctable:
    for client in ctable[node_ip]:
        client["node_ip_address"] = node_ip
        client_list.append(client)

client_df = pd.DataFrame(client_list)
client_df
# Out:
#         AuxAddress        ClientType  \
# 0              NaN  global_scheduler
# 1  127.0.0.1:36608   local_scheduler
# 2              NaN    plasma_manager
#
#                                  DBClientID  Deleted LocalSchedulerSocketName  \
# 0  4d90367d8cc32e0567889c8b63aa555be9149790    False                      NaN
# 1  14c2bbeb473224903782dd69a1b39fee6169d9e0    False   /tmp/scheduler97845365
# 2  64a51115bc235abe807f141c10b976ef18868a8b    False                      NaN
#
#    NumCPUs  NumGPUs node_ip_address
# 0      NaN      NaN       127.0.0.1
# 1      3.0      0.0       127.0.0.1
# 2      NaN      NaN       127.0.0.1

# %% [markdown]
# ### Object Store

# %%
# We can populate a DataFrame with a list of objects in the object store
object_dict = {oid.hex(): v for oid, v in ray.global_state.object_table().items()}
object_df = pd.DataFrame(object_dict).transpose()
object_df
# Out:
#                                           IsPut  \
# 115e4f27616a6b1457c8da4e7222e4cafa50b1b7  False
# 13be739628c9b0c0e3509b12fe4aa3a4541d8c64  False
# 24ec6afb09062f4c0aa7a4d062d083d96f867aae  False
# 3a72f0f6ae22bbd9999563caeb841470420d108b  False
# 3fbe45b82d8d814fc357c0801a5a440c07eae99d  False
# 40b908122a743a65f633760227ad8736a498629b  False
# 411e44da18845058f31dcf3c168ecd42d06d6907  False
# 4625f6cd52ab4d6e795abff885efe6632a36fe41  False
# 4e55dc7d4c66cc986aa35a19812325771336a699  False
# 5bbb611db726187a2ea93eb3a4843159ad19598a  False
# 7105d29b39ff45d1dcc78f32632aaa7400131c9e  False
# 75c88ac9512cdd1aa679224401297c8e8acb0701  False
# 7f50082075771db7062da393ab4561547434630c  False
# 90e340d22908163518a16e94ddd839a5a6306696  False
# 9d3ba1fbf53375afe4f58af29da03693996cd433  False
# a2c95d3bfb06539737766935a75bd0504aea4f29  False
# a2d1f943ee16df4dc3d8da96586c25e14277cc1f  False
# a365784561c5d5de0604eac54f2909c4fb038368  False
# abceaeffad917befd14c41c491bbe0e5c966b7c9  False
# b7f3b10821f4bb76a3b8ee30e9fe895b58ab989a  False
# bb0f6952d0eeb2677e97d1e8847f508c5b625eb0  False
# bd1ab29d7b1c14074621406290bcf5633e3ccf4e  False
# bdf43a11564a84f0b53c69467a031249a3dca29e  False
# c4fef7f814893b78266c9bd6ee73741c047df51b  False
# eb6f9a754f11b5894d00c0565a74a46ca5eba79e  False
# f660389055216920a73e9fb082f4ac7de983c842  False
# fa9ac2503e920b75abe8072ba77fbcbe061ab34f  False
# faffad4346e67a29b5549c6be5428111cf9c80f7  False
# fd82097f4a7fc25747a52f4b28a02625a1cd7231  False
#
#                                                                           ManagerIDs  \
# 115e4f27616a6b1457c8da4e7222e4cafa50b1b7  [64a51115bc235abe807f141c10b976ef18868a8b]
# 13be739628c9b0c0e3509b12fe4aa3a4541d8c64  [64a51115bc235abe807f141c10b976ef18868a8b]
# 24ec6afb09062f4c0aa7a4d062d083d96f867aae  [64a51115bc235abe807f141c10b976ef18868a8b]
# fa9ac2503e920b75abe8072ba77fbcbe061ab34f  fb9ac2503e920b75abe8072ba77fbcbe061ab34f
# faffad4346e67a29b5549c6be5428111cf9c80f7  fbffad4346e67a29b5549c6be5428111cf9c80f7
# fd82097f4a7fc25747a52f4b28a02625a1cd7231  fc82097f4a7fc25747a52f4b28a02625a1cd7231

# %% [markdown]
# ### Object - Worker Placement Information

# %%
# Objects associated with each worker_id 
object_table = ray.global_state.object_table()
location_to_objects = dict()

for object_id, object_descriptor in object_table.items():
        for location in object_descriptor["ManagerIDs"]:
            if location not in location_to_objects:
                location_to_objects[location] = []
            location_to_objects[location].append(object_id)
table = pd.DataFrame.from_dict(location_to_objects)
table
# Out:
#              64a51115bc235abe807f141c10b976ef18868a8b
# 0   ObjectID(90e340d22908163518a16e94ddd839a5a6306...
# 1   ObjectID(eb6f9a754f11b5894d00c0565a74a46ca5eba...
# 2   ObjectID(f660389055216920a73e9fb082f4ac7de983c...
# 3   ObjectID(abceaeffad917befd14c41c491bbe0e5c966b...
# 4   ObjectID(3a72f0f6ae22bbd9999563caeb841470420d1...
# 5   ObjectID(fd82097f4a7fc25747a52f4b28a02625a1cd7...
# 6   ObjectID(115e4f27616a6b1457c8da4e7222e4cafa50b...
# 7   ObjectID(fa9ac2503e920b75abe8072ba77fbcbe061ab...
# 8   ObjectID(bb0f6952d0eeb2677e97d1e8847f508c5b625...
# 9   ObjectID(c4fef7f814893b78266c9bd6ee73741c047df...
# 10  ObjectID(75c88ac9512cdd1aa679224401297c8e8acb0...
# 11  ObjectID(411e44da18845058f31dcf3c168ecd42d06d6...
# 12  ObjectID(4625f6cd52ab4d6e795abff885efe6632a36f...
# 13  ObjectID(9d3ba1fbf53375afe4f58af29da03693996cd...
# 14  ObjectID(faffad4346e67a29b5549c6be5428111cf9c8...
# 15  ObjectID(5bbb611db726187a2ea93eb3a4843159ad195...
# 16  ObjectID(bdf43a11564a84f0b53c69467a031249a3dca...
# 17  ObjectID(bd1ab29d7b1c14074621406290bcf5633e3cc...
# 18  ObjectID(b7f3b10821f4bb76a3b8ee30e9fe895b58ab9...
# 19  ObjectID(a2d1f943ee16df4dc3d8da96586c25e14277c...
# 20  ObjectID(a365784561c5d5de0604eac54f2909c4fb038...
# 21  ObjectID(40b908122a743a65f633760227ad8736a4986...
# 22  ObjectID(4e55dc7d4c66cc986aa35a19812325771336a...
# 23  ObjectID(7105d29b39ff45d1dcc78f32632aaa7400131...
# 24  ObjectID(24ec6afb09062f4c0aa7a4d062d083d96f867...
# 25  ObjectID(3fbe45b82d8d814fc357c0801a5a440c07eae...
# 26  ObjectID(a2c95d3bfb06539737766935a75bd0504aea4...
# 27  ObjectID(13be739628c9b0c0e3509b12fe4aa3a4541d8...
# 28  ObjectID(7f50082075771db7062da393ab45615474346...
